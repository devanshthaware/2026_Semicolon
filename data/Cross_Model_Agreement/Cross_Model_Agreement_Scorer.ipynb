# %% [markdown]
# # Cross-Model Agreement Scorer

# %%
import pandas as pd
from sklearn.metrics import mean_squared_error
df=pd.read_csv("cross_model_agreement_dataset_10000.csv")
print(df.head())
print("Average agreement:",df["agreement_score"].mean())

# %% [markdown]
# Production version should compute embeddings + cosine similarity + NLI.
