# %% [markdown]
# # Claim Extraction (Baseline Prompt/Seq2Seq Dataset Explorer)

# %%
import pandas as pd, json
df=pd.read_csv("claim_extraction_dataset_10000.csv")
df["atomic_claims"]=df["atomic_claims"].apply(json.loads)
df.head()

# %% [markdown]
# This notebook prepares data for fine-tuning a T5/BART model or evaluating prompt-based extraction.

# %%
print(df.iloc[0]["response"])
print(df.iloc[0]["atomic_claims"])
